# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ca-oshpd-adveventhospitalizationspsi-county2005-2015q3.csv')

# %% [markdown]
# # Descriptory Information

# %%
df.head(20)
# Out:
#     Year     County  PSI                                     PSIDescription  \
# 0   2005  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 1   2006  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 2   2007  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 3   2008  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 4   2009  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 5   2010  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 6   2011  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 7   2012  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 8   2013  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 9   2014  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 10  2015  STATEWIDE   21  Retained Surgical Item or Unretrieved Device F...
# 11  2005    Alameda   21  Retained Surgical Item or Unretrieved Device F...
# 12  2006    Alameda   21  Retained Surgical Item or Unretrieved Device F...
# 13  2007    Alameda   21  Retained Surgical Item or Unretrieved Device F...
# 14  2008    Alameda   21  Retained Surgical Item or Unretrieved Device F...
# 15  2009    Alameda   21  Retained Surgical Item or Unretrieved Device F...
# 16  2010    Alameda   21  Retained Surgical Item or Unretrieved Device F...
# 17  2011    Alameda   21  Retained Surgical Item or Unretrieved Device F...
# 18  2012    Alameda   21  Retained Surgical Item or Unretrieved Device F...
# 19  2013    Alameda   21  Retained Surgical Item or Unretrieved Device F...
#
#    Count    Population  ObsRate
# 0   321    26,447,738      1.21
# 1   341    26,679,904      1.28
# 2   353    26,935,982      1.31
# 3   346    27,272,108      1.27
# 4   308    27,630,962      1.11
# 5   292    28,000,783      1.04
# 6   305    28,396,854      1.07
# 7   290    27,818,703      1.04
# 8   255    28,195,720      0.90
# 9   235    28,842,368      0.81
# 10  153    21,475,301      0.71
# 11   18     1,102,068      1.63
# 12   12     1,106,823      1.08
# 13    8     1,117,973      0.72
# 14   19     1,136,417      1.67
# 15    6     1,155,287      0.52
# 16   11     1,169,910      0.94
# 17   17     1,186,810      1.43
# 18   12     1,173,980      1.02
# 19   10     1,197,759      0.83

# %%
df.describe()
# Out:
#               Year         PSI      ObsRate
# count  4543.000000  4543.00000  4543.000000
# mean   2010.000000    24.00000    11.663159
# std       3.162626     2.00022    15.894882
# min    2005.000000    21.00000     0.000000
# 25%    2007.000000    22.00000     0.000000
# 50%    2010.000000    24.00000     3.780000
# 75%    2013.000000    26.00000    20.360000
# max    2015.000000    27.00000   198.220000

# %% [markdown]
# #### What are the most common PSI descriptions?

# %%
psi = df['PSIDescription'].unique()
print(psi)
# Out:
# ['Retained Surgical Item or Unretrieved Device Fragment'
#  'Iatrogenic Pneumothorax'
#  'Central Venous Catheter-Related Blood Stream Infection'
#  'Postoperative Wound Dehiscence' 'Accidental Puncture or Laceration'
#  'Transfusion Reaction' 'Perioperative Hemorrhage or Hematoma']

# %%
d = {'Retained Surgical Item or Unretrieved Device Fragment': 0, 
     'Iatrogenic Pneumothorax': 0,
     'Central Venous Catheter-Related Blood Stream Infection': 0,
     'Postoperative Wound Dehiscence': 0,
     'Accidental Puncture or Laceration': 0,
     'Transfusion Reaction': 0,
     'Perioperative Hemorrhage or Hematoma': 0}

# %%
for x in df['PSIDescription']:
    for key in d:
        if key == x:
            d[key] = d[key] + 1
print(d)
# Out:
# {'Retained Surgical Item or Unretrieved Device Fragment': 649, 'Iatrogenic Pneumothorax': 649, 'Central Venous Catheter-Related Blood Stream Infection': 649, 'Postoperative Wound Dehiscence': 649, 'Accidental Puncture or Laceration': 649, 'Transfusion Reaction': 649, 'Perioperative Hemorrhage or Hematoma': 649}

# %% [markdown]
# # EDA

# %%
df_pair = df
df_pair = df_pair.drop('County', axis=1)
df_pair.head()
# Out:
#    Year  PSI                                     PSIDescription Count  \
# 0  2005   21  Retained Surgical Item or Unretrieved Device F...  321
# 1  2006   21  Retained Surgical Item or Unretrieved Device F...  341
# 2  2007   21  Retained Surgical Item or Unretrieved Device F...  353
# 3  2008   21  Retained Surgical Item or Unretrieved Device F...  346
# 4  2009   21  Retained Surgical Item or Unretrieved Device F...  308
#
#      Population  ObsRate
# 0   26,447,738      1.21
# 1   26,679,904      1.28
# 2   26,935,982      1.31
# 3   27,272,108      1.27
# 4   27,630,962      1.11

# %%
sns.pairplot(df_pair, hue='PSIDescription')
# Out:
# /Users/mohammedkabbashi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/mohammedkabbashi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/mohammedkabbashi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/mohammedkabbashi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/mohammedkabbashi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/mohammedkabbashi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/mohammedkabbashi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/mohammedkabbashi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Looking into a pairplot with just ObsRate

# %%
obs_rate = df_pair
obs_rate = obs_rate.drop('Year', axis=1)
obs_rate = obs_rate.drop('PSI', axis=1)
obs_rate = obs_rate.drop('Count', axis=1)
obs_rate = obs_rate.drop('Population', axis=1)
obs_rate.head()
# Out:
#                                       PSIDescription  ObsRate
# 0  Retained Surgical Item or Unretrieved Device F...     1.21
# 1  Retained Surgical Item or Unretrieved Device F...     1.28
# 2  Retained Surgical Item or Unretrieved Device F...     1.31
# 3  Retained Surgical Item or Unretrieved Device F...     1.27
# 4  Retained Surgical Item or Unretrieved Device F...     1.11

# %%
sns.pairplot(obs_rate, hue='PSIDescription', height=10)
plt.legend(labels=psi)
plt.show()
# Out:
# /Users/mohammedkabbashi/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
